# %% [markdown]
# # Bijgebouw 2021

# %%
import pandas as pd
import numpy as np
import folium
from branca.element import Figure
from folium.plugins import MarkerCluster

# %%
df1 = pd.read_excel(r"C:\Users\Gebruiker\Desktop\GITHUB\Geomatics\book21_edited.xlsx")

df1.head()
# Out:
#    Nummer                               H  \
# 0  210004  het plaatsen van een dakkapel
# 1  210039   het plaatsen van een dakkapel
# 2  210092   het plaatsen van een dakkapel
# 3  210172   het plaatsen van een dakkapel
# 4  210227  Het plaatsen van 2 dakkapellen
#
#                                              Address   Latitude  Longitude
# 0  1, Zeistpad, Stedenwijk, Almere Stad, Almere, ...  52.363841   5.203593
# 1  34, Barneveldpad, Stedenwijk, Almere Stad, Alm...  52.362509   5.208172
# 2  35, Breitnerstraat, Tussen de Vaarten, Almere,...  52.379402   5.254923
# 3  12, Beuvenstraat, Waterwijk, Almere, Flevoland...  52.386438   5.221712
# 4  8, Kaatsheuvelstraat, Stedenwijk, Almere, Flev...  52.357661   5.201078

# %%
locations = df1[['Latitude','Longitude']]
locationlist = locations.values.tolist()
len(locationlist)
locationlist[7]
# Out:
# [52.3885517, 5.2397798]

# %%
loc = 'Bijgebouw Aanvragen 2021'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   

map = folium.Map(location=[52.371320, 5.222381], zoom_start=12)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=df1['H'][point]).add_to(map)

# %%
def temp(map):
    fig2=Figure(width=1000,height=800)
    fig2.add_child(map)
    folium.TileLayer('Stamen Terrain').add_to(map)
    folium.TileLayer('Stamen Toner').add_to(map)
    folium.TileLayer('Stamen Water Color').add_to(map)
    folium.TileLayer('cartodbpositron').add_to(map)
    folium.TileLayer('cartodbdark_matter').add_to(map)
    folium.LayerControl().add_to(map)
    map.get_root().html.add_child(folium.Element(title_html))


def save(map):
    map.save('map-with-title.html')

# %%
# map.save('map-with-title.html')
temp(map)
map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95201cebe75cbb6eb74cc0aa45a3127a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Bijgebouw Aanvragen 2021&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95201cebe75cbb6eb74cc0aa45a3127a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95201cebe75cbb6eb74cc0aa45a3127a = L.map(
#                 &quot;map_95201cebe75cbb6eb74cc0aa45a3127a&quot;,
#                 {
#                     center: [52.37132, 5.222381],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3943f779361cd1c60b3a221877ef1ade = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_95201cebe75cbb6eb74cc0aa45a3127a);
#
#
#             var marker_7f7865af31ba6b57a2d336a030a12021 = L.marker(
#                 [52.3638407, 5.2035925],
#                 {}
#             ).addTo(map_95201cebe75cbb6eb74cc0aa45a3127a);
#
#
#         var popup_4dabee9bca69d0cba3edd00072ea943f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1da88f55b37d4e0a96a213db1e2315ca = $(`&lt;div id=&quot;html_1da88f55b37d4e0a96a213db1e2315ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel &lt;/div&gt;`)[0];
#                 popup_4dabee9bca69d0cba3edd00072ea943f.setContent(html_1da88f55b37d4e0a96a213db1e2315ca);
#
#
#
#         marker_7f7865af31ba6b57a2d336a030a12021.bindPopup(popup_4dabee9bca69d0cba3edd00072ea943f)
#         ;
#
#
#
#
#             var marker_4dd5067a0c0c879293dedb9c37a98174 = L.marker(
#                 [52.3625089, 5.2081716],
#                 {}
#             ).addTo(map_95201cebe75cbb6eb74cc0aa45a3127a);
#
#
#         var popup_e102a7076b0268609c0ca2e58d3abe62 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ffb559a2d33240b3e7c42f19052b94a = $(`&lt;div id=&quot;html_6ffb559a2d33240b3e7c42f19052b94a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel&lt;/div&gt;`)[0];
#                 popup_e102a7076b0268609c0ca2e58d3abe62.setContent(html_6ffb559a2d33240b3e7c42f19052b94a);
#
#
#
#         marker_4dd5067a0c0c879293dedb9c37a98174.bindPopup(popup_e102a7076b0268609c0ca2e58d3abe62)
#         ;
#
#
#
#
#             var marker_9b3f74937b3114b5296b2fc5a1f4b19c = L.marker(
#                 [52.3794021, 5.2549227],
#                 {}
#             ).addTo(map_95201cebe75cbb6eb74cc0aa45a3127a);
#
#
#         var popup_950868d76862dfc013f82986bd13fa5a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3263a5c512a1106f78849f28896c3ea1 = $(`&lt;div id=&quot;html_3263a5c512a1106f78849f28896c3ea1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel&lt;/div&gt;`)[0];
#                 popup_950868d76862dfc013f82986bd13fa5a.setContent(html_3263a5c512a1106f78849f28896c3ea1);
#
#
#
#         marker_9b3f74937b3114b5296b2fc5a1f4b19c.bindPopup(popup_950868d76862dfc013f82986bd13fa5a)
#         ;
#
#
#
#
#             var marker_546eb3288125309a256e4faea109a460 = L.marker(
#                 [52.3864381, 5.2217125],
#                 {}
#             ).addTo(map_95201cebe75cbb6eb74cc0aa45a3127a);
#
#
#         var popup_a222e3531f65d096a870f5d2aa57d6cb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16d5b39a18f68e31d4ada4a2e54f0f66 = $(`&lt;div id=&quot;html_16d5b39a18f68e31d4ada4a2e54f0f66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel&lt;/div&gt;`)[0];
#                 popup_a222e3531f65d096a870f5d2aa57d6cb.setContent(html_16d5b39a18f68e31d4ada4a2e54f0f66);
#
#
#
#         marker_546eb3288125309a256e4faea109a460.bindPopup(popup_a222e3531f65d096a870f5d2aa57d6cb)
#         ;
#
#
#
#
#             var marker_f5a4366d2183dc00dbd50c65953c5440 = L.marker(
#                 [52.3576613, 5.2010784],
#                 {}
#             ).addTo(map_95201cebe75cbb6eb74cc0aa45a3127a);
#
#
#         var popup_5c66b4e7b6ad2d004aaf0260658cd955 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_01954dc81b8dcf0c15c05e82f517057a = $(`&lt;div id=&quot;html_01954dc81b8dcf0c15c05e82f517057a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Het plaatsen van 2 dakkapellen&lt;/div&gt;`)[0];
#                 popup_5c66b4e7b6ad2d004aaf0260658cd955.setContent(html_01954dc81b8dcf0c15c05e82f517057a);
#
#
#
#         marker_f5a4366d2183dc00dbd50c65953c5440.bindPopup(popup_5c66b4e7b6ad2d004aaf0260658cd955)
#         ;
#
#
#
#
#             var marker_f39cbdd5b0373cf4c7d883e6eb0c8860 = L.marker(
#                 [52.3571639, 5.1459849],
#                 {}
#             ).addTo(map_95201cebe75cbb6eb74cc0aa45a3127a);

# %%
map2 = folium.Map(location=[52.371320, 5.222381], tiles='CartoDB dark_matter', zoom_start=11)


marker_cluster = MarkerCluster().add_to(map2)

for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=df1['H'][point]).add_to(marker_cluster)


temp(map2)
map2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_088eb55faf5b8ea20628ef9c7cd10a97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Bijgebouw Aanvragen 2021&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_088eb55faf5b8ea20628ef9c7cd10a97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_088eb55faf5b8ea20628ef9c7cd10a97 = L.map(
#                 &quot;map_088eb55faf5b8ea20628ef9c7cd10a97&quot;,
#                 {
#                     center: [52.37132, 5.222381],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63485704c273a1270c11d24811407778 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_088eb55faf5b8ea20628ef9c7cd10a97);
#
#
#             var marker_cluster_32b5785fd9abb8746b7e3da352b0fe5f = L.markerClusterGroup(
#                 {}
#             );
#             map_088eb55faf5b8ea20628ef9c7cd10a97.addLayer(marker_cluster_32b5785fd9abb8746b7e3da352b0fe5f);
#
#
#             var marker_6df2557481c2de56b4b3c7fdfa95a9e6 = L.marker(
#                 [52.3638407, 5.2035925],
#                 {}
#             ).addTo(marker_cluster_32b5785fd9abb8746b7e3da352b0fe5f);
#
#
#         var popup_8efca20eddaed7d5bd16b0a8be8f8804 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d59544e6c87afa233f7764a570242172 = $(`&lt;div id=&quot;html_d59544e6c87afa233f7764a570242172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel &lt;/div&gt;`)[0];
#                 popup_8efca20eddaed7d5bd16b0a8be8f8804.setContent(html_d59544e6c87afa233f7764a570242172);
#
#
#
#         marker_6df2557481c2de56b4b3c7fdfa95a9e6.bindPopup(popup_8efca20eddaed7d5bd16b0a8be8f8804)
#         ;
#
#
#
#
#             var marker_19854a166314a0f213b426e59bdb4042 = L.marker(
#                 [52.3625089, 5.2081716],
#                 {}
#             ).addTo(marker_cluster_32b5785fd9abb8746b7e3da352b0fe5f);
#
#
#         var popup_fafa7743e67276674ab60662c2335689 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5332b504183a5f48dd33f47e04f43a1d = $(`&lt;div id=&quot;html_5332b504183a5f48dd33f47e04f43a1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel&lt;/div&gt;`)[0];
#                 popup_fafa7743e67276674ab60662c2335689.setContent(html_5332b504183a5f48dd33f47e04f43a1d);
#
#
#
#         marker_19854a166314a0f213b426e59bdb4042.bindPopup(popup_fafa7743e67276674ab60662c2335689)
#         ;
#
#
#
#
#             var marker_01b26d706679f96440689bd8876d7e8d = L.marker(
#                 [52.3794021, 5.2549227],
#                 {}
#             ).addTo(marker_cluster_32b5785fd9abb8746b7e3da352b0fe5f);
#
#
#         var popup_92d2e9d8a6455ec00165f560452027e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_af6b2545b6e475ba34dedc08feaeb4c6 = $(`&lt;div id=&quot;html_af6b2545b6e475ba34dedc08feaeb4c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel&lt;/div&gt;`)[0];
#                 popup_92d2e9d8a6455ec00165f560452027e0.setContent(html_af6b2545b6e475ba34dedc08feaeb4c6);
#
#
#
#         marker_01b26d706679f96440689bd8876d7e8d.bindPopup(popup_92d2e9d8a6455ec00165f560452027e0)
#         ;
#
#
#
#
#             var marker_574bcc4950842c8b075dc700ecd1396b = L.marker(
#                 [52.3864381, 5.2217125],
#                 {}
#             ).addTo(marker_cluster_32b5785fd9abb8746b7e3da352b0fe5f);
#
#
#         var popup_e07b181a54eecb9eee907a1e3f61cefb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_865d7a8724810b85df79b6d2dc021947 = $(`&lt;div id=&quot;html_865d7a8724810b85df79b6d2dc021947&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel&lt;/div&gt;`)[0];
#                 popup_e07b181a54eecb9eee907a1e3f61cefb.setContent(html_865d7a8724810b85df79b6d2dc021947);
#
#
#
#         marker_574bcc4950842c8b075dc700ecd1396b.bindPopup(popup_e07b181a54eecb9eee907a1e3f61cefb)
#         ;
#
#
#
#
#             var marker_6e436cca80450f2202ce07b123fdb0e1 = L.marker(
#                 [52.3576613, 5.2010784],
#                 {}

# %%
map2 = folium.Map(location=[52.371320, 5.222381], tiles='Stamen Terrain', zoom_start=11)

marker_cluster = MarkerCluster().add_to(map2)

for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=df1['H'][point], icon=folium.Icon(color='darkblue', icon_color='white', icon='male', angle=0, prefix='fa')).add_to(marker_cluster)

temp(map2)
map2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7691bf206c0128d6ab29aa84dcd8cae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Bijgebouw Aanvragen 2021&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7691bf206c0128d6ab29aa84dcd8cae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7691bf206c0128d6ab29aa84dcd8cae = L.map(
#                 &quot;map_f7691bf206c0128d6ab29aa84dcd8cae&quot;,
#                 {
#                     center: [52.37132, 5.222381],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54f021dcbcdcab3d2d922de79d4d68c2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f7691bf206c0128d6ab29aa84dcd8cae);
#
#
#             var marker_cluster_d4dc2069a738c1699fbf3352d6776527 = L.markerClusterGroup(
#                 {}
#             );
#             map_f7691bf206c0128d6ab29aa84dcd8cae.addLayer(marker_cluster_d4dc2069a738c1699fbf3352d6776527);
#
#
#             var marker_be2a02db8d085889ad606816083e5b45 = L.marker(
#                 [52.3638407, 5.2035925],
#                 {}
#             ).addTo(marker_cluster_d4dc2069a738c1699fbf3352d6776527);
#
#
#             var icon_0bb5aabf9b08a666551ba1fc2b4e65e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_be2a02db8d085889ad606816083e5b45.setIcon(icon_0bb5aabf9b08a666551ba1fc2b4e65e6);
#
#
#         var popup_47e4ed11cf32d4b573b4dfdab68897d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b34cc96d054277f6b7d86ecafdb71af6 = $(`&lt;div id=&quot;html_b34cc96d054277f6b7d86ecafdb71af6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel &lt;/div&gt;`)[0];
#                 popup_47e4ed11cf32d4b573b4dfdab68897d9.setContent(html_b34cc96d054277f6b7d86ecafdb71af6);
#
#
#
#         marker_be2a02db8d085889ad606816083e5b45.bindPopup(popup_47e4ed11cf32d4b573b4dfdab68897d9)
#         ;
#
#
#
#
#             var marker_94cbdbfbf4ab959dd9eba517415ae546 = L.marker(
#                 [52.3625089, 5.2081716],
#                 {}
#             ).addTo(marker_cluster_d4dc2069a738c1699fbf3352d6776527);
#
#
#             var icon_8d56c55d8432df5ba9f2f8eaa704e244 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_94cbdbfbf4ab959dd9eba517415ae546.setIcon(icon_8d56c55d8432df5ba9f2f8eaa704e244);
#
#
#         var popup_f650a2b8d32854eb7bdab2017905df4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db7be70f13de1d52e0f0269f495d50ba = $(`&lt;div id=&quot;html_db7be70f13de1d52e0f0269f495d50ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;het plaatsen van een dakkapel&lt;/div&gt;`)[0];
#                 popup_f650a2b8d32854eb7bdab2017905df4e.setContent(html_db7be70f13de1d52e0f0269f495d50ba);
#
#
#
#         marker_94cbdbfbf4ab959dd9eba517415ae546.bindPopup(popup_f650a2b8d32854eb7bdab2017905df4e)
#         ;
#
#
#
#
#             var marker_7bf422104fe46029b2655e6f58c4ee9b = L.marker(
#                 [52.3794021, 5.2549227],
#                 {}
#             ).addTo(marker_cluster_d4dc2069a738c1699fbf3352d6776527);
#
#
#             var icon_909e253150e3d612dcf5220cc672b46d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7bf422104fe46029b2655e6f58c4ee9b.setIcon(icon_909e253150e3d612dcf5220cc672b46d);
#
#
#         var popup_fa4aedd870d985226f32224e86dd8ec8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_469f62069bccac9472

# %% [markdown]
# The terrain map is an improvement over the dark map, but I still found the green coloring for natural areas to be distracting from the main objective of the map. I now also want to differentiate the counters by region. To do that, I decided to create a function to assign a unique color to each region.

# %%
def regioncolors(df1):
    if df1['H'] == 'het plaatsen van een dakkapel':
        return 'green'
    elif df1['H'] == 'Het plaatsen van aanbouw':
        return 'blue'
    elif df1['H'] == 'het plaatsen van een dakopbouw':
        return 'red'
    else:
        return 'darkblue'
df1["color"] = df1.apply(regioncolors, axis=1)
df1.head()
# Out:
#    Nummer                               H  \
# 0  210004  het plaatsen van een dakkapel
# 1  210039   het plaatsen van een dakkapel
# 2  210092   het plaatsen van een dakkapel
# 3  210172   het plaatsen van een dakkapel
# 4  210227  Het plaatsen van 2 dakkapellen
#
#                                              Address   Latitude  Longitude  \
# 0  1, Zeistpad, Stedenwijk, Almere Stad, Almere, ...  52.363841   5.203593
# 1  34, Barneveldpad, Stedenwijk, Almere Stad, Alm...  52.362509   5.208172
# 2  35, Breitnerstraat, Tussen de Vaarten, Almere,...  52.379402   5.254923
# 3  12, Beuvenstraat, Waterwijk, Almere, Flevoland...  52.386438   5.221712
# 4  8, Kaatsheuvelstraat, Stedenwijk, Almere, Flev...  52.357661   5.201078
#
#       color
# 0  darkblue
# 1     green
# 2     green
# 3     green
# 4  darkblue

# %% [markdown]
# I then changed the point icon color for each counter based on its region. I also switched the basemap to the lighter CartoDB positron tiles. While I was at it, I also realized it would be a really good idea to include the counter ID number on the map since you need that number when making specific API calls for counter data.

# %%
map3 = folium.Map(location=[52.371320, 5.222381], tiles='CartoDB positron', zoom_start=11)

marker_cluster = MarkerCluster().add_to(map3)

for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup='ID:'+str(df1['Nummer'][point])+' '+df1['H'][point], icon=folium.Icon(color=df1["color"][point], icon_color='white', icon='home', angle=0, prefix='fa')).add_to(marker_cluster)
temp(map3)
map3
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70fc85b88403209619209c9a052fe52b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#              &lt;h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;&gt;&lt;b&gt;Bijgebouw Aanvragen 2021&lt;/b&gt;&lt;/h3&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70fc85b88403209619209c9a052fe52b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70fc85b88403209619209c9a052fe52b = L.map(
#                 &quot;map_70fc85b88403209619209c9a052fe52b&quot;,
#                 {
#                     center: [52.37132, 5.222381],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9346ee91aec6cf9b5558ebc8ad36797 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70fc85b88403209619209c9a052fe52b);
#
#
#             var marker_cluster_db6e3a30f8b3e10c7b7d756bf5b10606 = L.markerClusterGroup(
#                 {}
#             );
#             map_70fc85b88403209619209c9a052fe52b.addLayer(marker_cluster_db6e3a30f8b3e10c7b7d756bf5b10606);
#
#
#             var marker_9d7a92b76c77b0e4138325b2cae350df = L.marker(
#                 [52.3638407, 5.2035925],
#                 {}
#             ).addTo(marker_cluster_db6e3a30f8b3e10c7b7d756bf5b10606);
#
#
#             var icon_96fc5bc68f69a905a7d42263a3b155ea = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9d7a92b76c77b0e4138325b2cae350df.setIcon(icon_96fc5bc68f69a905a7d42263a3b155ea);
#
#
#         var popup_a0a7f0114c5cefe3f4a0cb9ebbbf5d7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4617074c49a4c40b8feef289f8ed9165 = $(`&lt;div id=&quot;html_4617074c49a4c40b8feef289f8ed9165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID:210004 het plaatsen van een dakkapel &lt;/div&gt;`)[0];
#                 popup_a0a7f0114c5cefe3f4a0cb9ebbbf5d7b.setContent(html_4617074c49a4c40b8feef289f8ed9165);
#
#
#
#         marker_9d7a92b76c77b0e4138325b2cae350df.bindPopup(popup_a0a7f0114c5cefe3f4a0cb9ebbbf5d7b)
#         ;
#
#
#
#
#             var marker_a9bd69b3b46acbcd11223475361e5803 = L.marker(
#                 [52.3625089, 5.2081716],
#                 {}
#             ).addTo(marker_cluster_db6e3a30f8b3e10c7b7d756bf5b10606);
#
#
#             var icon_795ce9517b8dc3f5e6bf7c7e00763df6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a9bd69b3b46acbcd11223475361e5803.setIcon(icon_795ce9517b8dc3f5e6bf7c7e00763df6);
#
#
#         var popup_9ccff3555b60344a259bc376634e19d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d016a7fd4e5d0bbe9b920a7676b89696 = $(`&lt;div id=&quot;html_d016a7fd4e5d0bbe9b920a7676b89696&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ID:210039 het plaatsen van een dakkapel&lt;/div&gt;`)[0];
#                 popup_9ccff3555b60344a259bc376634e19d1.setContent(html_d016a7fd4e5d0bbe9b920a7676b89696);
#
#
#
#         marker_a9bd69b3b46acbcd11223475361e5803.bindPopup(popup_9ccff3555b60344a259bc376634e19d1)
#         ;
#
#
#
#
#             var marker_500b8bc3e326a4d0f9654511f05d8926 = L.marker(
#                 [52.3794021, 5.2549227],
#                 {}
#             ).addTo(marker_cluster_db6e3a30f8b3e10c7b7d756bf5b10606);
#
#
#             var icon_ea8e177128dd5e4e4d37ca98f7ef5198 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_500b8bc3e326a4d0f9654511f05d8926.setIcon(icon_ea8e177128dd5e4e4d37ca98f7ef5198);
#
#
#         var popup_53debdcf3be65ee4ada36d39c9c7c4ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18b434deb294ed5f499017d7d1052cd2 = $(`&lt;div id=&quot;html_18b434deb294ed5f499017

# %%
# save(map3)

# %%
from IPython.core.display import display, HTML

htmlmap = HTML('<iframe srcdoc="{}" style="float:left; width: {}px; height: {}px; display:inline-block; width: 49%; margin: 0 auto; border: 3px solid black"></iframe>'
           '<iframe srcdoc="{}" style="float:right; width: {}px; height: {}px; display:inline-block; width: 49%; margin: 0 auto; border: 3px solid black"></iframe>'
           .format(map2.get_root().render().replace('"', '&quot;'),500,500,
                   map3.get_root().render().replace('"', '&quot;'),500,500))
display(htmlmap)
# Out:
# C:\Users\Gebruiker\AppData\Local\Temp\ipykernel_17024\318966639.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# c:\Users\Gebruiker\anaconda3\lib\site-packages\IPython\core\display.py:419: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe srcdoc="<!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; />
#
#         <script>
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         </script>
#
#     <style>html, body {width: 100%;height: 100%;margin: 0;padding: 0;}</style>
#     <style>#map {position:absolute;top:0;bottom:0;right:0;left:0;}</style>
#     <script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;></script>
#     <script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;></script>
#     <script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;></script>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/>
#
#             <meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; />
#             <style>
#                 #map_f7691bf206c0128d6ab29aa84dcd8cae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             </style>
#
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;></script>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/>
#     <link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/>
# </head>
# <body>
#
#
#              <h3 align=&quot;center&quot; style=&quot;font-size:16px&quot;><b>Bijgebouw Aanvragen 2021</b></h3>
#
#
#             <div class=&quot;folium-map&quot; id=&quot;map_f7691bf206c0128d6ab29aa84dcd8cae&quot; ></div>
#
# </body>
# <script>
#
#
#             var map_f7691bf206c0128d6ab29aa84dcd8cae = L.map(
#                 &quot;map_f7691bf206c0128d6ab29aa84dcd8cae&quot;,
#                 {
#                     center: [52.37132, 5.222381],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54f021dcbcdcab3d2d922de79d4d68c2 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f7691bf206c0128d6ab29aa84dcd8cae);
#
#
#             var marker_cluster_d4dc2069a738c1699fbf3352d6776527 = L.markerClusterGroup(
#                 {}
#             );
#             map_f7691bf206c0128d6ab29aa84dcd8cae.addLayer(marker_cluster_d4dc2069a738c1699fbf3352d6776527);
#
#
#             var marker_be2a02db8d085889ad606816083e5b45 = L.marker(
#                 [52.3638407, 5.2035925],
#                 {}
#             ).addTo(marker_cluster_d4dc2069a738c1699fbf3352d6776527);
#
#
#             var icon_0bb5aabf9b08a666551ba1fc2b4e65e6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_be2a02db8d085889ad606816083e5b45.setIcon(icon_0bb5aabf9b08a666551ba1fc2b4e65e6);
#
#
#         var popup_47e4ed11cf32d4b573b4dfdab68897d9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b34cc96d054277f6b7d86ecafdb71af6 = $(`<div id=&quot;html_b34cc96d054277f6b7d86ecafdb71af6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;>het plaatsen van een dakkapel </div>`)[0];
#                 popup_47e4ed11cf32d4b573b4dfdab68897d9.setContent(html_b34cc96d054277f6b7d86ecafdb71af6);
#
#
#
#         marker_be2a02db8d085889ad606816083e5b45.bindPopup(popup_47e4ed11cf32d4b573b4dfdab68897d9)
#         ;
#
#
#
#
#             var marker_94cbdbfbf4ab959dd9eba517415ae546 = L.marker(
#                 [52.3625089, 5.2081716],
#                 {}
#             ).addTo(marker_cluster_d4dc2069a738c1699fbf3352d6776527);
#
#
#             var icon_8d56c55d8432df5ba9f2f8eaa704e244 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_94cbdbfbf4ab959dd9eba517415ae546.setIcon(icon_8d56c55d8432df5ba9f2f8eaa704e244);
#
#
#         var popup_f650a2b8d32854eb7bdab2017905df4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db7be70f13de1d52e0f0269f495d50ba = $(`<div id=&quot;html_db7be70f13de1d52e0f0269f495d50ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;>het plaatsen van een dakkapel</div>`)[0];
#                 popup_f650a2b8d32854eb7bdab2017905df4e.setContent(html_db7be70f13de1d52e0f0269f495d50ba);
#
#
#
#         marker_94cbdbfbf4ab959dd9eba517415ae546.bindPopup(popup_f650a2b8d32854eb7bdab2017905df4e)
#         ;
#
#
#
#
#             var marker_7bf422104fe46029b2655e6f58c4ee9b = L.marker(
#                 [52.3794021, 5.2549227],
#                 {}
#             ).addTo(marker_cluster_d4dc2069a738c1699fbf3352d6776527);
#
#
#             var icon_909e253150e3d612dcf5220cc672b46d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;male&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7bf422104fe46029b2655e6f58c4ee9b.setIcon(icon_909e253150e3d612dcf5220cc672b46d);
#
#
#         var popup_fa4aedd870d985226f32224e86dd8ec8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_469f62069bccac9472987f3f58e3e6a3 = $(`<div id=&quot;html_469f62069bccac9472987f3f58e3e6a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;>het plaatsen van een dakkapel</div>`)[0];
#                 popup_fa4aedd870d985226f32224e86dd8ec8.setContent(html_469f62069bccac9472987f3f58e3e6
